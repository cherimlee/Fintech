# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

import requests
from bs4 import BeautifulSoup

import os
from tqdm import tqdm

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import FinanceDataReader as fdr

# %%
# KT&G 주가 2005~Now
# 4263 rows

ktng = fdr.DataReader('033780', '2005-01-01', '2022-04-04')
ktng.head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2005-01-03  31000  31150  30650  30650  259867 -0.009693
# 2005-01-04  30850  31250  30650  31000  321100  0.011419
# 2005-01-05  31000  31650  30900  31500  635585  0.016129
# 2005-01-06  31850  31900  31000  31000  420824 -0.015873
# 2005-01-07  31150  31500  31000  31200  296535  0.006452

# %%
ktng.tail(5)
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2022-03-29  81000  81100  80500  81100  157378  0.003713
# 2022-03-30  81300  81300  80600  80900  204322 -0.002466
# 2022-03-31  81000  81200  80600  80700  250995 -0.002472
# 2022-04-01  80500  81100  80400  81000  199768  0.003717
# 2022-04-04  81000  81400  80900  81400  158622  0.004938

# %%
ktng
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2005-01-03  31000  31150  30650  30650  259867 -0.009693
# 2005-01-04  30850  31250  30650  31000  321100  0.011419
# 2005-01-05  31000  31650  30900  31500  635585  0.016129
# 2005-01-06  31850  31900  31000  31000  420824 -0.015873
# 2005-01-07  31150  31500  31000  31200  296535  0.006452
# ...           ...    ...    ...    ...     ...       ...
# 2022-03-29  81000  81100  80500  81100  157378  0.003713
# 2022-03-30  81300  81300  80600  80900  204322 -0.002466
# 2022-03-31  81000  81200  80600  80700  250995 -0.002472
# 2022-04-01  80500  81100  80400  81000  199768  0.003717
# 2022-04-04  81000  81400  80900  81400  158622  0.004938
#
# [4266 rows x 6 columns]

# %%
ktg = fdr.DataReader('033780', '2005')
ktg['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
book = pd.read_excel("./Book.xlsx")
book
# Out:
#      Unnamed: 0    매출액  영업이익  영업이익률
# 0    2005-01-01   3964   968   24.4
# 1    2005-01-02   3964   968   24.4
# 2    2005-01-03   3964   968   24.4
# 3    2005-01-04   3964   968   24.4
# 4    2005-01-05   3964   968   24.4
# ...         ...    ...   ...    ...
# 6298 2022-03-31  12761  3125   24.5
# 6299 2022-04-01  12761  3125   24.5
# 6300 2022-04-02  12761  3125   24.5
# 6301 2022-04-03  12761  3125   24.5
# 6302 2022-04-04  12761  3125   24.5
#
# [6303 rows x 4 columns]

# %%
book.columns = ['Date','매출액', '영업이익', '영업이익률']

# %%
book.Date
# Out:
# 0      2005-01-01
# 1      2005-01-02
# 2      2005-01-03
# 3      2005-01-04
# 4      2005-01-05
#           ...
# 6298   2022-03-31
# 6299   2022-04-01
# 6300   2022-04-02
# 6301   2022-04-03
# 6302   2022-04-04
# Name: Date, Length: 6303, dtype: datetime64[ns]

# %%
ktng_merge = pd.merge(ktng, book, how='outer', on='Date')

# %%
ktng_merge
# Out:
#            Date     Open     High      Low    Close    Volume    Change  \
# 0    2005-01-03  31000.0  31150.0  30650.0  30650.0  259867.0 -0.009693
# 1    2005-01-04  30850.0  31250.0  30650.0  31000.0  321100.0  0.011419
# 2    2005-01-05  31000.0  31650.0  30900.0  31500.0  635585.0  0.016129
# 3    2005-01-06  31850.0  31900.0  31000.0  31000.0  420824.0 -0.015873
# 4    2005-01-07  31150.0  31500.0  31000.0  31200.0  296535.0  0.006452
# ...         ...      ...      ...      ...      ...       ...       ...
# 6298 2022-03-20      NaN      NaN      NaN      NaN       NaN       NaN
# 6299 2022-03-26      NaN      NaN      NaN      NaN       NaN       NaN
# 6300 2022-03-27      NaN      NaN      NaN      NaN       NaN       NaN
# 6301 2022-04-02      NaN      NaN      NaN      NaN       NaN       NaN
# 6302 2022-04-03      NaN      NaN      NaN      NaN       NaN       NaN
#
#         매출액  영업이익  영업이익률
# 0      3964   968   24.4
# 1      3964   968   24.4
# 2      3964   968   24.4
# 3      3964   968   24.4
# 4      3964   968   24.4
# ...     ...   ...    ...
# 6298  12761  3125   24.5
# 6299  12761  3125   24.5
# 6300  12761  3125   24.5
# 6301  12761  3125   24.5
# 6302  12761  3125   24.5
#
# [6303 rows x 10 columns]

# %% [markdown]
# 매출액 : KT&G의 총 매출액
# 영업이익 : 영업활동을 통하여 획득한 이익(손실), 전체 매출액에서 제조에 들어가는 매출원가와 영업활동에 들어가는 비용인 판관비를 제외하고 남은 수익
# 영업이익률 : 제조 단계에서 원가가 높거나 판매 단계에서 효율적이지 못하면 영업이익률이 떨어지게 된다
# = 영업이익/매출액 x 100 :

# %%
ktng_merge = ktng_merge[0:4266]

# %%
ktng_merge
# Out:
#            Date     Open     High      Low    Close    Volume    Change  \
# 0    2005-01-03  31000.0  31150.0  30650.0  30650.0  259867.0 -0.009693
# 1    2005-01-04  30850.0  31250.0  30650.0  31000.0  321100.0  0.011419
# 2    2005-01-05  31000.0  31650.0  30900.0  31500.0  635585.0  0.016129
# 3    2005-01-06  31850.0  31900.0  31000.0  31000.0  420824.0 -0.015873
# 4    2005-01-07  31150.0  31500.0  31000.0  31200.0  296535.0  0.006452
# ...         ...      ...      ...      ...      ...       ...       ...
# 4261 2022-03-29  81000.0  81100.0  80500.0  81100.0  157378.0  0.003713
# 4262 2022-03-30  81300.0  81300.0  80600.0  80900.0  204322.0 -0.002466
# 4263 2022-03-31  81000.0  81200.0  80600.0  80700.0  250995.0 -0.002472
# 4264 2022-04-01  80500.0  81100.0  80400.0  81000.0  199768.0  0.003717
# 4265 2022-04-04  81000.0  81400.0  80900.0  81400.0  158622.0  0.004938
#
#         매출액  영업이익  영업이익률
# 0      3964   968   24.4
# 1      3964   968   24.4
# 2      3964   968   24.4
# 3      3964   968   24.4
# 4      3964   968   24.4
# ...     ...   ...    ...
# 4261  12761  3125   24.5
# 4262  12761  3125   24.5
# 4263  12761  3125   24.5
# 4264  12761  3125   24.5
# 4265  12761  3125   24.5
#
# [4266 rows x 10 columns]

# %%
ktng_merge.set_index('Date',inplace=True)
ktng_merge = ktng_merge.astype('float')
ktng_merge
# Out:
#                Open     High      Low    Close    Volume    Change      매출액  \
# Date
# 2005-01-03  31000.0  31150.0  30650.0  30650.0  259867.0 -0.009693   3964.0
# 2005-01-04  30850.0  31250.0  30650.0  31000.0  321100.0  0.011419   3964.0
# 2005-01-05  31000.0  31650.0  30900.0  31500.0  635585.0  0.016129   3964.0
# 2005-01-06  31850.0  31900.0  31000.0  31000.0  420824.0 -0.015873   3964.0
# 2005-01-07  31150.0  31500.0  31000.0  31200.0  296535.0  0.006452   3964.0
# ...             ...      ...      ...      ...       ...       ...      ...
# 2022-03-29  81000.0  81100.0  80500.0  81100.0  157378.0  0.003713  12761.0
# 2022-03-30  81300.0  81300.0  80600.0  80900.0  204322.0 -0.002466  12761.0
# 2022-03-31  81000.0  81200.0  80600.0  80700.0  250995.0 -0.002472  12761.0
# 2022-04-01  80500.0  81100.0  80400.0  81000.0  199768.0  0.003717  12761.0
# 2022-04-04  81000.0  81400.0  80900.0  81400.0  158622.0  0.004938  12761.0
#
#               영업이익  영업이익률
# Date
# 2005-01-03   968.0   24.4
# 2005-01-04   968.0   24.4
# 2005-01-05   968.0   24.4
# 2005-01-06   968.0   24.4
# 2005-01-07   968.0   24.4
# ...            ...    ...
# 2022-03-29  3125.0   24.5
# 2022-03-30  3125.0   24.5
# 2022-03-31  3125.0   24.5
# 2022-04-01  3125.0   24.5
# 2022-04-04  3125.0   24.5
#
# [4266 rows x 9 columns]

# %%
ktng_merge.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# Change    float64
# 매출액       float64
# 영업이익      float64
# 영업이익률     float64
# dtype: object

# %%
ktng_merge.shape
# Out:
# (4266, 9)

# %%
scaler = MinMaxScaler()

# %%
price = scaler.fit_transform(ktng_merge)

# %%
price = scaler.fit_transform(ktng_merge)
price[:3]
# Out:
# array([[0.01022305, 0.00321987, 0.00804163, 0.006539  , 0.0246721 ,
#         0.37907277, 0.        , 0.        , 0.21959459],
#        [0.008829  , 0.00413983, 0.00804163, 0.0098085 , 0.03206319,
#         0.48567394, 0.        , 0.        , 0.21959459],
#        [0.01022305, 0.00781969, 0.01040681, 0.01447922, 0.07002292,
#         0.50945478, 0.        , 0.        , 0.21959459]])

# %%
window_size = 10
X = []
Y = []

for i in range(len(price) - window_size):
  X.append([price[i+j] for j in range(window_size)])
  Y.append(price[window_size + i][0])

# %%
X = np.array(X)
Y = np.array(Y)

# %%
X.shape
# Out:
# (4256, 10, 9)

# %%
Y.shape
# Out:
# (4256,)

# %%
# 80:20 
tt_split = 3400

x_train = X[:tt_split]
y_train = Y[:tt_split]

x_test = X[tt_split:]
y_test = Y[tt_split:]

# %%
x_train.shape
# Out:
# (3400, 10, 9)

# %%
y_train.shape
# Out:
# (3400,)

# %%
x_test.shape
# Out:
# (856, 10, 9)

# %%
y_test.shape
# Out:
# (856,)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(10, 9)))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 100)               44000
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_9 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 44,101
# Trainable params: 44,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(x_train, y_train, epochs=20, batch_size=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 340/340 [==============================] - 2s 4ms/step - loss: 2.7810e-04 - val_loss: 6.3732e-05
# Epoch 2/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.6538e-04 - val_loss: 8.5724e-05
# Epoch 3/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.9109e-04 - val_loss: 3.8751e-05
# Epoch 4/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.5710e-04 - val_loss: 4.2379e-05
# Epoch 5/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.6099e-04 - val_loss: 7.4576e-05
# Epoch 6/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.6819e-04 - val_loss: 9.2515e-05
# Epoch 7/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.4530e-04 - val_loss: 5.1332e-05
# Epoch 8/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.4383e-04 - val_loss: 5.2270e-05
# Epoch 9/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.2204e-04 - val_loss: 1.7709e-04
# Epoch 10/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.5677e-04 - val_loss: 4.7612e-05
# Epoch 11/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.3988e-04 - val_loss: 4.0676e-05
# Epoch 12/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.2185e-04 - val_loss: 4.8228e-05
# Epoch 13/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.3575e-04 - val_loss: 3.6609e-05
# Epoch 14/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.2440e-04 - val_loss: 1.9266e-04
# Epoch 15/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.5250e-04 - val_loss: 1.1404e-04
# Epoch 16/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.1655e-04 - val_loss: 1.3117e-04
# Epoch 17/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.3991e-04 - val_loss: 6.1089e-05
# Epoch 18/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.2301e-04 - val_loss: 5.0362e-05
# Epoch 19/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.2892e-04 - val_loss: 7.9959e-05
# Epoch 20/20
# 340/340 [==============================] - 1s 4ms/step - loss: 2.2163e-04 - val_loss: 4.4305e-05

# %%
x_train_pred = model.predict(x_train)
x_test_pred = model.predict(x_test)

# %%
plt.figure(figsize=(15,5))

plt.plot(price[-856:,0], color='b',label='Real')
plt.plot(x_test_pred[-856:], color='r',label='Predict')
plt.style.use('ggplot')
plt.legend(loc='best', ncol=2) 
plt.show()

# %%
model = Sequential()
model.add(SimpleRNN(8, input_shape=(10,9)))
model.add(Dense(1, activation='tanh'))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_5 (SimpleRNN)    (None, 8)                 144
#
#  dense_8 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 153
# Trainable params: 153
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
hist = model.fit(x_train.astype(float), y_train, epochs=30, batch_size=64, validation_data=(x_test.astype(float), y_test))
# Out:
# Epoch 1/30
# 54/54 [==============================] - 1s 5ms/step - loss: 5.2306 - accuracy: 2.9412e-04 - val_loss: 5.2031 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7634 - accuracy: 2.9412e-04 - val_loss: 1.2597 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6531 - accuracy: 5.8824e-04 - val_loss: 1.1246 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6334 - accuracy: 5.8824e-04 - val_loss: 0.7564 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6228 - accuracy: 5.8824e-04 - val_loss: 0.7189 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 5.8824e-04 - val_loss: 0.7006 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6147 - accuracy: 5.8824e-04 - val_loss: 0.6905 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6141 - accuracy: 5.8824e-04 - val_loss: 0.6824 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6161 - accuracy: 5.8824e-04 - val_loss: 0.6872 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6118 - accuracy: 5.8824e-04 - val_loss: 0.6829 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 5.8824e-04 - val_loss: 0.6816 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 5.8824e-04 - val_loss: 0.6807 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6106 - accuracy: 5.8824e-04 - val_loss: 0.6787 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6101 - accuracy: 5.8824e-04 - val_loss: 0.6783 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 5.8824e-04 - val_loss: 0.6776 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6095 - accuracy: 5.8824e-04 - val_loss: 0.6771 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6098 - accuracy: 5.8824e-04 - val_loss: 0.6766 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6094 - accuracy: 5.8824e-04 - val_loss: 0.6763 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 5.8824e-04 - val_loss: 0.6760 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6084 - accuracy: 5.8824e-04 - val_loss: 0.6758 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6081 - accuracy: 5.8824e-04 - val_loss: 0.6756 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6077 - accuracy: 5.8824e-04 - val_loss: 0.6753 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6076 - accuracy: 5.8824e-04 - val_loss: 0.6751 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6078 - accuracy: 5.8824e-04 - val_loss: 0.6753 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 5.8824e-04 - val_loss: 0.6749 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 5.8824e-04 - val_loss: 0.6746 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 5.8824e-04 - val_loss: 0.6746 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6066 - accuracy: 5.8824e-04 - val_loss: 0.6744 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6065 - accuracy: 5.8824e-04 - val_loss: 0.6744 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6091 - accuracy: 5.8824e-04 - val_loss: 0.6778 - val_accuracy: 0.0000e+00
