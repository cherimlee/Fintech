# %%
import numpy as np
import pandas as pd
import cv2
import PIL
import pytesseract
import easyocr

# %%
import easyocr
reader = easyocr.Reader(['ko', 'en'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import easyocr
# ----> 2 reader = easyocr.Reader(['ko', 'en'])
#
# File ~/docuscan/lib/python3.9/site-packages/easyocr/easyocr.py:223, in Reader.__init__(self, lang_list, gpu, model_storage_directory, user_network_directory, recog_network, download_enabled, detector, recognizer, verbose, quantize, cudnn_benchmark)
#     220     dict_list[lang] = os.path.join(BASE_PATH, 'dict', lang + ".txt")
#     222 if detector:
# --> 223     self.detector = get_detector(detector_path, self.device, quantize, cudnn_benchmark=cudnn_benchmark)
#     224 if recognizer:
#     225     if recog_network == 'generation1':
#
# File ~/docuscan/lib/python3.9/site-packages/easyocr/detection.py:85, in get_detector(trained_model, device, quantize, cudnn_benchmark)
#      83             pass
#      84 else:
# ...
