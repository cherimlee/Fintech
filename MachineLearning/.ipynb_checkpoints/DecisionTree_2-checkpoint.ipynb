# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loans = pd.read_csv('./ml_source_files/loan_data.csv')
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0
# 4            1        0               0

# %%
# 대출 가능 여부 판단
# 데이터 - 고객의 특성에 따라 default 여부가 있는 데이터
# decisiontree, randomforest를 통해서 예측 모델 생성, 테스트

# %%
loans.tail()
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 9573       12.180755  10.39   672       10474.000000     215372        82.1
# 9574       11.141862   0.21   722        4380.000000        184         1.1
# 9575       10.596635  13.09   687        3450.041667      10036        82.9
# 9576       10.819778  19.18   692        1800.000000          0         3.2
# 9577       11.264464  16.28   732        4740.000000      37879        57.0
#
#       inq.last.6mths  delinq.2yrs  pub.rec  not.fully.paid
# 9573               2            0        0               1
# 9574               5            0        0               1
# 9575               8            0        0               1
# 9576               5            0        0               1
# 9577               6            0        0               1

# %%
y = loans['not.fully.paid']              
x = loans.drop(['not.fully.paid'], axis=1)

# %%
# object => one_hot encoding
x = pd.get_dummies(x)  
x

# 주의 : 문자열 칼럼이 너무 길어질 수 있다 -> 머신러닝 학습에 방해
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0           5639.958333      28854        52.1               0            0
# 1           2760.000000      33623        76.7               0            0
# 2           4710.000000       3511        25.6               1            0
# 3           2699.958333      33667        73.2               1            0
# 4           4066.000000       4740        39.5               0            1
# ...                 ...        ...         ...             ...          ...
# 9573       10474.000000     215372        82.1               2            0
# 9574        4380.000000        184         1.1               5            0
# 9575        3450.041667      10036        82.9               8            0
# 9576        1800.000000          0         3.2               5            0
# 9577        4740.000000      37879        57.0               6            0
#
#       pub.rec  purpose_all_other  purpose_credit_card  \
# 0           0                  0                    0
# 1           0                  0                    1
# 2           0                  0                    0
# 3           0                  0                    0
# 4           0                  0                    1
# ...       ...                ...                  ...
# 9573        0                  1                    0
# 9574        0                  1                    0
# 9575        0                  0                    0
# 9576        0                  0                    0
# 9577        0                  0                    0
#
#       purpose_debt_consolidation  purpose_educational  \
# 0                              1                    0
# 1                              0                    0
# 2                              1                    0
# 3                              1                    0
# 4                              0                    0
# ...                          ...                  ...
# 9573                           0                    0
# 9574                           0                    0
# 9575                           1                    0
# 9576                           0                    0
# 9577                           1                    0
#
#       purpose_home_improvement  purpose_major_purchase  purpose_small_business
# 0                            0                       0                       0
# 1                            0                       0                       0
# 2                            0                       0                       0
# 3                            0                       0                       0
# 4                            0                       0                       0
# ...                        ...                     ...                     ...
# 9573                         0                       0                       0
# 9574                         0                       0                       0
# 9575                         0                       0                       0
# 9576                         1                       0                       0
# 9577                         0                       0                       0
#
# [9578 rows x 19 columns]

# %%
x.purpose.nunique()
# Out:
# 7

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=111)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
preds = tree.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      1635
#            1       0.19      0.24      0.21       281
#
#     accuracy                           0.74      1916
#    macro avg       0.53      0.53      0.53      1916
# weighted avg       0.76      0.74      0.75      1916

# %%
from sklearn.model_selection import GridSearchCV

params = {'n_estimators' : [50, 100, 500],
          "max_depth":[10,20,50],
          "min_samples_leaf" : [2,5]}
rfc = RandomForestClassifier()
grid = GridSearchCV(rfc, param_grid = params, refit=True, verbose=True)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 50], 'min_samples_leaf': [2, 5],
#                          'n_estimators': [50, 100, 500]},
#              verbose=True)

# %%
grid.best_params_

# %%
grid.best_score

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 20)

# %%
rfc.fit(x_train, y_train)
preds_rfc = rfc.predict(x_test)
print(classification_report(y_test, preds_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      1635
#            1       0.36      0.05      0.09       281
#
#     accuracy                           0.85      1916
#    macro avg       0.61      0.52      0.50      1916
# weighted avg       0.78      0.85      0.80      1916

# %%
rfc.feature_importances_
# Out:
# array([0.01554577, 0.10174102, 0.11394585, 0.10902444, 0.10786818,
#        0.07978631, 0.11076104, 0.10998056, 0.11036326, 0.05697746,
#        0.01518282, 0.00922044, 0.01162288, 0.00767324, 0.01292993,
#        0.00594605, 0.00670087, 0.00463476, 0.01009514])

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(10,7))
plot_tree(tree)
plt.show()
