# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
df_tesla = pd.read_csv('./테슬라 총합.csv')
df_tesla
# Out:
#       Unnamed: 0        date   tesla  tesla_거래량  tesla_volatility  elec_fee  \
# 0              0  2015-01-02   43.86    23820.0             -1.39      6.67
# 1              1  2015-01-05   42.02    26840.0             -4.20      6.67
# 2              2  2015-01-06   42.26    31310.0              0.57      6.67
# 3              3  2015-01-07   42.19    14840.0             -0.17      6.67
# 4              4  2015-01-08   42.12    17210.0             -0.17      6.67
# ...          ...         ...     ...        ...               ...       ...
# 1802        1802  2022-02-28  870.43    32770.0              7.48      7.16
# 1803        1803  2022-03-01  864.37    24720.0             -0.70      7.16
# 1804        1804  2022-03-02  879.89    24650.0              1.80      7.16
# 1805        1805  2022-03-03  839.29    20260.0             -4.61      7.16
# 1806        1806  2022-03-04  838.29    22390.0             -0.12      7.16
#
#       oli_price  oli_price_volatility  carbon_credits  \
# ...

# %%
df_tesla.columns
# Out:
# Index(['Unnamed: 0', 'date', 'tesla', 'tesla_거래량', 'tesla_volatility',
#        'elec_fee', 'oli_price', 'oli_price_volatility', 'carbon_credits',
#        'carbon_credits_volatility', 'EVE종가', 'EVE거래량', 'EVE변동률', 'BYD종가',
#        'BYD거래량', 'BYD변동률', 'PSI종가', 'PSI거래량', 'SOXX종가', 'SOXX거래량', 'SOXL종가',
#        'SOXL거래량', 'LIT조정종가', 'LIT거래량', 'SGL종가', 'SGL변동률', 'li_price', 'co',
#        'co_volatility', '희토류가격', 'nasdaq', 'nasdaq_거래량', 'nasdaq_volatility',
#        'ssec', 'ssec_거래량', 'ssec_volatility', 'dollar', 'dollar_volatility',
#        'alu_price', 'alu_vol', 'alu_change', 'cu_price', 'cu_change',
#        'REGI_price', 'REGI_vol', 'REGI_change'],
#       dtype='object')

# %%
df_tesla.isnull().sum()
# Out:
# Unnamed: 0                   0
# date                         0
# tesla                        0
# tesla_거래량                    0
# tesla_volatility             0
# elec_fee                     0
# oli_price                    0
# oli_price_volatility         0
# carbon_credits               0
# carbon_credits_volatility    0
# EVE종가                        0
# EVE거래량                       0
# EVE변동률                       0
# BYD종가                        0
# BYD거래량                       0
# BYD변동률                       0
# PSI종가                        0
# PSI거래량                       0
# SOXX종가                       0
# SOXX거래량                      0
# SOXL종가                       0
# SOXL거래량                      0
# LIT조정종가                      0
# LIT거래량                       0
# SGL종가                        0
# SGL변동률                       0
# li_price                     0
# co                           0
# co_volatility                0
# 희토류가격                        0
# ...

# %%
np.std(df_tesla['carbon_credits'])
# Out:
# 19.380391783190152

# %%
y = df_tesla['tesla']
x = df_tesla.drop(['tesla', 'date', 'Unnamed: 0',
                  'kodex_volatility', 'snp_500_volatility', 'tiger_거래량', '매출원가',
       'tiger_volatility', '순이익', '매출총이익', 'EVE종가', '매출액', 'EVE거래량', 'batt',
       'tbx_거래량', 'batt_거래량', 'ssec_volatility', 'tbx_volatility', 'alu_vol',
       'ACDC종가', 'PSI거래량', 'BYD거래량', 'oil_price'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7648/2070874960.py in <module>
#       1 y = df_tesla['tesla']
# ----> 2 x = df_tesla.drop(['tesla', 'date', 'Unnamed: 0',
#       3                   'kodex_volatility', 'snp_500_volatility', 'tiger_거래량', '매출원가',
#       4        'tiger_volatility', '순이익', '매출총이익', 'EVE종가', '매출액', 'EVE거래량', 'batt',
#       5        'tbx_거래량', 'batt_거래량', 'ssec_volatility', 'tbx_volatility', 'alu_vol',
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# Index(['자산총계', 'LIT조정종가', 'kodex', 'kars', 'kodex_거래량', '주가수익배수PER(배)',
#        'DRIV거래량', 'SOXL종가', 'REGI_price', '검색량', '매출총이익률', 'tiger',
#        'oil_price_volatility', 'tesla_거래량', 'BYD변동률', '희토류가격',
#        'nasdaq_volatility', 'batt_volatility', 'cu_price', 'alu_change',
#        'li_price', 'LIT거래량', 'co', 'PSI종가', 'SOXX종가', 'SOXX거래량', 'kars_거래량',
#        'SOXL거래량', 'ACDC거래량', 'ssec', 'SGL종가', 'SGL변동률', 'alu_price',
#        '총자산이익률ROA(%)', 'co_volatility', 'nasdaq', 'nasdaq_거래량', '주당순이익EPS(달러)',
#        'ssec_거래량', 'dollar', 'dollar_volatility', 'carbon_credits', '영업이익',
#        '영업이익률', 'EVE변동률', 'kars_volatility', 'tbx', 'cu_change', 'DRIV종가',
#        'REGI_vol', 'REGI_change', 'snp_500', 'carbon_credits_volatility',
#        'BYD종가',

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.2, random_state=111)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
preds = lr.predict(x_test)
preds
# Out:
# array([  35.90586283,   92.49614031, 1044.7617014 , ...,   73.67148594,
#         717.83342161,   73.97325483])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, preds)
# Out:
# 0.9771895835783243

# %%
# 'carbon_credits', 'EVE종가', 'BYD종가'

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
lr_preds = lr.predict(x_test_scaled)

# %%
r2_score(y_test, lr_preds)
# Out:
# 0.9771895835760672

# %%
x_train.columns[1]
# Out:
# 'tesla_volatility'

# %%
for i in range(len(lr.coef_)):
    print(x_train.columns[i],lr.coef_[i])
# Out:
# tesla_거래량 6.623275197946799
# tesla_volatility 7.3114906733910825
# elec_fee 1.751613302202297
# oli_price -40.10801649188388
# oli_price_volatility -0.7718492812669986
# carbon_credits 14.771460612407884
# carbon_credits_volatility 1.800399701101768
# EVE종가 18.20245738407961
# EVE거래량 -6.743449048698354
# EVE변동률 4.173259477298621
# BYD종가 7.83254001723153
# BYD거래량 -4.943940905994609
# BYD변동률 0.5566628229650505
# PSI종가 -106.18785522127244
# PSI거래량 -1.13950136476902
# SOXX종가 -34.68979105373995
# SOXX거래량 7.5355132239130045
# SOXL종가 133.98394549553578
# SOXL거래량 -2.974620386309296
# LIT조정종가 70.67182369207617
# LIT거래량 -9.596652692388032
# SGL종가 18.6621709194838
# SGL변동률 4.3772329830962615
# li_price 45.46826190873436
# co -6.131692210358814
# co_volatility 2.3423908523084167
# 희토류가격 33.94778432178947
# nasdaq 91.34320196274604
# nasdaq_거래량 3.0662579974524515
# nasdaq_volatility -0.37905375760777116
# ssec 15.110801587337315
# ssec_거래량 5.261905081779894
# ssec_volatility -4.804415849039493
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_absolute_error
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoost

# %%
df_tesla
# Out:
#       Unnamed: 0        date   tesla  tesla_거래량  tesla_volatility  elec_fee  \
# 0              0  2015-01-02   43.86    23820.0             -1.39      6.67
# 1              1  2015-01-05   42.02    26840.0             -4.20      6.67
# 2              2  2015-01-06   42.26    31310.0              0.57      6.67
# 3              3  2015-01-07   42.19    14840.0             -0.17      6.67
# 4              4  2015-01-08   42.12    17210.0             -0.17      6.67
# ...          ...         ...     ...        ...               ...       ...
# 1802        1802  2022-02-28  870.43    32770.0              7.48      7.16
# 1803        1803  2022-03-01  864.37    24720.0             -0.70      7.16
# 1804        1804  2022-03-02  879.89    24650.0              1.80      7.16
# 1805        1805  2022-03-03  839.29    20260.0             -4.61      7.16
# 1806        1806  2022-03-04  838.29    22390.0             -0.12      7.16
#
#       oli_price  oli_price_volatility  carbon_credits  \
# ...

# %%
df_tesla.columns
# Out:
# Index(['Unnamed: 0', 'date', 'tesla', 'tesla_거래량', 'tesla_volatility',
#        'elec_fee', 'oli_price', 'oli_price_volatility', 'carbon_credits',
#        'carbon_credits_volatility', 'EVE종가', 'EVE거래량', 'EVE변동률', 'BYD종가',
#        'BYD거래량', 'BYD변동률', 'PSI종가', 'PSI거래량', 'SOXX종가', 'SOXX거래량', 'SOXL종가',
#        'SOXL거래량', 'LIT조정종가', 'LIT거래량', 'SGL종가', 'SGL변동률', 'li_price', 'co',
#        'co_volatility', '희토류가격', 'nasdaq', 'nasdaq_거래량', 'nasdaq_volatility',
#        'ssec', 'ssec_거래량', 'ssec_volatility', 'dollar', 'dollar_volatility',
#        'alu_price', 'alu_vol', 'alu_change', 'cu_price', 'cu_change',
#        'REGI_price', 'REGI_vol', 'REGI_change'],
#       dtype='object')

# %%
y = df_tesla['tesla_volatility']
x = df_tesla.drop(['date','tesla', 'elec_fee', 'tesla_volatility',\
                   ], axis=1)

# %%
df_tesla.iloc[1007]
# Out:
# Unnamed: 0                         1007
# date                         2019-01-02
# tesla                             62.02
# tesla_거래량                       58290.0
# tesla_volatility                  -6.82
# elec_fee                           6.58
# oli_price                         46.54
# oli_price_volatility               1.42
# carbon_credits                    26.57
# carbon_credits_volatility          1.03
# EVE종가                              8.37
# EVE거래량                          30370.0
# EVE변동률                             1.21
# BYD종가                             49.17
# BYD거래량                           8560.0
# BYD변동률                            -3.59
# PSI종가                             44.74
# PSI거래량                            36.15
# SOXX종가                           157.92
# SOXX거래량                           764.0
# SOXL종가                              5.7
# SOXL거래량                         13150.0
# LIT조정종가                       26.336552
# ...

# %%
y.hist(bins=50, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df_tesla['ssec_volatility'].hist(bins = 50, figsize = (10, 5))
# Out:
# <AxesSubplot:>

# %%
tr = int(len(df_tesla) / 100 * 80)
x_train, x_test = x.iloc[1007:1600], x.iloc[1600:]
y_train, y_test = y.iloc[1007:1600], y.iloc[1600:]

# %%
scaled = StandardScaler()
scaled.fit(x_train)
x_train_scaled = scaled.transform(x_train)
x_test_scaled = scaled.transform(x_test)

# %%
lr = LinearRegression()
lr.fit(x_train_scaled, y_train)
preds_lr = lr.predict(x_test_scaled)
print('train :', lr.score(x_train_scaled,y_train))
print('test :', lr.score(x_test_scaled,y_test))
# Out:
# train : 0.4266450814511642
# test : -6.779751810161623

# %%
rid = Ridge(alpha=100)
rid.fit(x_train_scaled, y_train)
preds_rid = rid.predict(x_test_scaled)
print('train :', rid.score(x_train_scaled,y_train))
print('test :', rid.score(x_test_scaled,y_test))
# Out:
# train : 0.4033129740449668
# test : 0.33395434747321917

# %%
las = Lasso(alpha=5)
las.fit(x_train_scaled, y_train)
preds_las = las.predict(x_test_scaled)
print('train :', las.score(x_train_scaled,y_train))
print('test :', las.score(x_test_scaled,y_test))
# Out:
# train : 0.0
# test : -0.0074003877063835155

# %%
xb = XGBRegressor()
xb.fit(x_train_scaled, y_train)
preds_xb = xb.predict(x_test_scaled)
print('train :', xb.score(x_train_scaled,y_train))
print('test :', xb.score(x_test_scaled,y_test))
# Out:
# train : 0.9999881910668086
# test : 0.2943151431586172

# %%
lgbm = LGBMRegressor()
lgbm.fit(x_train_scaled, y_train)
preds_lgbm = lgbm.predict(x_test_scaled)
print('train :', lgbm.score(x_train_scaled,y_train))
print('test :', lgbm.score(x_test_scaled,y_test))
# Out:
# train : 0.9583022416324087
# test : 0.32403036538998053

# %%
cat = CatBoost()
cat.fit(x_train_scaled, y_train)
preds_cat = cat.predict(x_test_scaled)
r2_score(y_test,preds_cat)
# print('train :', cat.score(x_train_scaled,y_train))
# print('test :', cat.score(x_test_scaled,y_test))
# Out:
# Learning rate set to 0.037698
# 0:	learn: 4.4767840	total: 150ms	remaining: 2m 29s
# 1:	learn: 4.4321020	total: 154ms	remaining: 1m 16s
# 2:	learn: 4.3850325	total: 158ms	remaining: 52.5s
# 3:	learn: 4.3414465	total: 162ms	remaining: 40.4s
# 4:	learn: 4.3052620	total: 166ms	remaining: 33.1s
# 5:	learn: 4.2732214	total: 171ms	remaining: 28.3s
# 6:	learn: 4.2472004	total: 175ms	remaining: 24.8s
# 7:	learn: 4.2051332	total: 180ms	remaining: 22.3s
# 8:	learn: 4.1742900	total: 185ms	remaining: 20.4s
# 9:	learn: 4.1418644	total: 190ms	remaining: 18.8s
# 10:	learn: 4.1081841	total: 195ms	remaining: 17.5s
# 11:	learn: 4.0794609	total: 199ms	remaining: 16.4s
# 12:	learn: 4.0471055	total: 204ms	remaining: 15.4s
# 13:	learn: 4.0128029	total: 208ms	remaining: 14.6s
# 14:	learn: 3.9814260	total: 212ms	remaining: 13.9s
# 15:	learn: 3.9550593	total: 217ms	remaining: 13.3s
# 16:	learn: 3.9235459	total: 221ms	remaining: 12.8s
# 17:	learn: 3.8921610	total: 225ms	remaining: 12.3s
# ...

# %%
y_log = np.log1p(y)
# log1p(n) = log(n+1) : 값이 0일때 error를 해결하기 위해
y_train_log = np.log1p(y_train)
y_test_log = np.log1p(y_test)

# %%
y_log.hist(bins=50, figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7648/1739500786.py in <module>
# ----> 1 y_log.hist(bins=50, figsize=(10,5))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      98     """
#      99     plot_backend = _get_plot_backend(backend)
# --> 100     return plot_backend.hist_series(
#     101         self,
#     102         by=by,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     352         if legend:
#     353             kwds["label"] = self.name
# --> 354         ax.hist(values, bins=bins, **kwds)
#     355         if legend:
#     356             ax.legend()
#
# ...

# %%
lr = LinearRegression()
rid = Ridge()
las = Lasso(alpha=0.0001)

lr.fit(x_train_scaled, y_train_log)
rid.fit(x_train_scaled, y_train_log)
las.fit(x_train_scaled, y_train_log)

preds_lr = lr.predict(x_test_scaled)
preds_rid = rid.predict(x_test_scaled)
preds_las = las.predict(x_test_scaled)

# exponential을 통해 log원복
preds_lr_exp = np.expm1(preds_lr)
preds_rid_exp = np.expm1(preds_rid)
preds_las_exp = np.expm1(preds_las)

# log를 취해 쏠린 label값을 조정해 준 것이 오차가 더 작다.
print('r2_score_lr :', r2_score(y_test, preds_lr_exp))
print('r2_score_rid :', r2_score(y_test, preds_rid_exp))
print('r2_score_las :', r2_score(y_test, preds_las_exp))

# %%
df_f = pd.read_csv('./테슬라 총합 재무제표.csv', index_col=0)
df_f
# Out:
#             date   tesla  tesla_거래량  tesla_volatility  elec_fee  oil_price  \
# 0     2015-01-02   43.86    23820.0             -1.39      6.67      52.69
# 1     2015-01-05   42.02    26840.0             -4.20      6.67      50.04
# 2     2015-01-06   42.26    31310.0              0.57      6.67      47.93
# 3     2015-01-07   42.19    14840.0             -0.17      6.67      48.65
# 4     2015-01-08   42.12    17210.0             -0.17      6.67      48.79
# ...          ...     ...        ...               ...       ...        ...
# 1822  2022-02-28  870.43    32770.0              7.48      7.16      95.72
# 1823  2022-03-01  864.37    24720.0             -0.70      7.16     103.41
# 1824  2022-03-02  879.89    24650.0              1.80      7.16     110.60
# 1825  2022-03-03  839.29    20260.0             -4.61      7.16     107.67
# 1826  2022-03-04  838.29    22390.0             -0.12      7.16     115.68
#
# ...

# %%
df_ = df_f.iloc[1027:]

# %%
df_ = df_.interpolate()

# %%
df_.tesla = df_.tesla.shift(-3)
df_.dropna(inplace=True)

# %%
df_
# Out:
#             date   tesla  tesla_거래량  tesla_volatility  elec_fee  oil_price  \
# 1027  2019-01-02   66.99    58290.0             -6.82      6.58      46.54
# 1028  2019-01-03   67.07    34830.0             -3.14      6.58      47.09
# 1029  2019-01-04   67.71    36970.0              5.78      6.58      47.96
# 1030  2019-01-07   68.99    37760.0              5.43      6.58      48.52
# 1031  2019-01-08   69.45    35040.0              0.12      6.58      49.78
# ...          ...     ...        ...               ...       ...        ...
# 1819  2022-02-23  870.43    31070.0             -7.00      7.16      92.10
# 1820  2022-02-24  864.37    44760.0              4.81      7.16      92.81
# 1821  2022-02-25  879.89    25360.0              1.14      7.16      91.59
# 1822  2022-02-28  839.29    32770.0              7.48      7.16      95.72
# 1823  2022-03-01  838.29    24720.0             -0.70      7.16     103.41
#
# ...

# %%
df_.isna().sum().sum()
# Out:
# 0

# %%
df_.columns
# Out:
# Index(['date', 'tesla', 'tesla_거래량', 'tesla_volatility', 'elec_fee',
#        'oil_price', 'oil_price_volatility', 'carbon_credits',
#        'carbon_credits_volatility', 'EVE종가', 'EVE거래량', 'EVE변동률', 'BYD종가',
#        'BYD거래량', 'BYD변동률', 'DRIV종가', 'DRIV거래량', 'ACDC종가', 'ACDC거래량', 'kars',
#        'kars_거래량', 'kars_volatility', 'batt', 'batt_거래량', 'batt_volatility',
#        'PSI종가', 'PSI거래량', 'SOXX종가', 'SOXX거래량', 'SOXL종가', 'SOXL거래량', 'LIT조정종가',
#        'LIT거래량', 'SGL종가', 'SGL변동률', 'li_price', 'co', 'co_volatility', '희토류가격',
#        'nasdaq', 'nasdaq_거래량', 'nasdaq_volatility', 'ssec', 'ssec_거래량',
#        'ssec_volatility', 'dollar', 'dollar_volatility', 'alu_price',
#        'alu_vol', 'alu_change', 'cu_price', 'cu_change', 'REGI_price',
#        'REGI_vol', 'REGI_change', 'snp_500', 'snp_500_volatility', 'kodex',
#        'kodex_거래량', 'kodex_volatility', 'tiger', 'tiger_거래량',
#        'tiger_volatility', 'tbx', 'tbx_거래량', 'tbx_volatility', '검색량', '매출액',
# ...

# %%
y = df_['tesla']
x = df_.drop(['tesla_volatility', 'date', 'tesla', 'elec_fee'], axis = 1)

# %%
x_train, x_test = x.iloc[:600], x.iloc[600:]
y_train, y_test = y.iloc[:600], y.iloc[600:]

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
preds_lr = lr.predict(x_test)
print('train :', lr.score(x_train,y_train))
print('test :', lr.score(x_test,y_test))
# Out:
# train : 0.9944474012920885
# test : -42.93846792349757

# %%
# 스케일링

scaled = StandardScaler()
scaled.fit(x_train)
x_train_scaled = scaled.transform(x_train)
x_test_scaled = scaled.transform(x_test)

# %%
# LinearRegression 

lr = LinearRegression()
lr.fit(x_train_scaled, y_train)
preds_lr = lr.predict(x_test_scaled)
print('train :', lr.score(x_train_scaled,y_train))
print('test :', lr.score(x_test_scaled,y_test))
# Out:
# train : 0.994439747883368
# test : -42.77681311475405

# %%
preds_lr
# Out:
# array([  597.51220232,   619.87803407,   628.94427933,   636.21636108,
#          640.63384626,   620.74967801,   611.92800976,   622.13049019,
#          605.74632195,   619.2996537 ,   643.54048545,   639.29423071,
#          612.58671589,   600.32754764,   601.50587939,   598.49671114,
#          589.20835983,   583.94919158,   585.37752333,   613.86835508,
#          605.79668684,   624.94583552,   625.65541727,   622.33374902,
#          631.44958078,   621.65916253,   639.63611378,   633.64289296,
#          626.69622471,   650.64416731,   652.2796099 ,   624.7537794 ,
#          605.13922199,   642.96216459,   641.00385718,   645.73863238,
#          644.78032497,   616.75951756,   623.5773593 ,   648.05655189,
#          657.49412966,   636.59832225,   650.95251484,   633.24420744,
#          626.53590003,   616.9109778 ,   580.39017039,   583.36936298,
#          598.12470472,   565.91639731,   542.35397508,   554.83316767,
# ...

# %%
# Ridge

train_score = []
test_score = []
alpha_list = list(np.arange(0.01, 1000, 0.01))

for alpha in alpha_list:
    rid = Ridge(alpha=alpha)
    rid.fit(x_train_scaled, y_train)
    train_score.append(rid.score(x_train_scaled, y_train))
    test_score.append(rid.score(x_test_scaled, y_test))
    preds_rid = rid.predict(x_test_scaled)
print(train_score)
print(test_score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7648/3631183996.py in <module>
#       7 for alpha in alpha_list:
#       8     rid = Ridge(alpha=alpha)
# ----> 9     rid.fit(x_train_scaled, y_train)
#      10     train_score.append(rid.score(x_train_scaled, y_train))
#      11     test_score.append(rid.score(x_test_scaled, y_test))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     760         self : returns an instance of self.
#     761         """
# --> 762         return super().fit(X, y, sample_weight=sample_weight)
#     763
#     764
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     591                 params = {}
#     592
# --> 593             self.coef_, self.n_iter_ = _ridge_regression(
# ...

# %%
preds_rid

# %%
plt.plot(np.log10(alpha_list), train_score)
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %%
rid = Ridge(alpha=0.05)
rid.fit(x_train_scaled, y_train)
print(rid.score(x_train_scaled, y_train))
print(rid.score(x_test_scaled, y_test))

# %%
# Lasso

train_score = []
test_score = []
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

for alpha in alpha_list:
    las = Lasso(alpha=alpha)
    las.fit(x_train_scaled, y_train)
    train_score.append(las.score(x_train_scaled, y_train))
    test_score.append(las.score(x_test_scaled, y_test))
    preds_las = las.predict(x_test_scaled)
print(train_score)
print(test_score)
# Out:
# [0.9938930932052422, 0.9939332273387921, 0.9934352823182171, 0.9880396725885469, 0.9834228254323637, 0.8197272151641036]
# [-1.3312865805559082, -0.9576898237229652, 0.20468581338043534, 0.5982958479302887, 0.597546826767334, -0.2867558941502628]

# %%
plt.plot(np.log10(alpha_list), train_score)
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %%
las = Lasso(alpha=1)
las.fit(x_train_scaled, y_train)
preds = las.predict(x_test_scaled)
print(las.score(x_train_scaled, y_train))
print(las.score(x_test_scaled, y_test))
# Out:
# 0.9880396725885469
# 0.5982958479302887

# %%
y_test.index
# Out:
# Int64Index([1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636,
#             ...
#             1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823],
#            dtype='int64', length=197)

# %%
sns.set(rc={'figure.figsize':(15,5)})
plt.plot(y_test.index, y_test,'r--', range(1627,1824),preds,'b--' )

# %%
coef_df = pd.DataFrame(las.coef_, index = x_train.columns)
coef_df = coef_df.sort_values(0, ascending=False)

# %%
plt.rcParams['font.family'] = 'Nanum Brush Script'
sns.set(rc = {'figure.figsize':(10,20)})
sns.barplot(x=coef_df[0].sort_values(ascending=False), y=coef_df.index)
# Out:
# <AxesSubplot:xlabel='0'>

# %%
coef_df.sort_values(0, ascending=False).index
# Out:
# Index(['자산총계', 'LIT조정종가', 'kodex', 'kars', 'kodex_거래량', '주가수익배수PER(배)',
#        'DRIV거래량', 'SOXL종가', 'REGI_price', '검색량', '매출총이익률', 'tiger',
#        'oil_price_volatility', 'tesla_거래량', 'BYD변동률', '희토류가격',
#        'nasdaq_volatility', 'batt_volatility', 'cu_price', 'alu_change',
#        'li_price', 'LIT거래량', 'co', 'PSI종가', 'SOXX종가', 'SOXX거래량', 'kars_거래량',
#        'SOXL거래량', 'ACDC거래량', 'ssec', 'SGL종가', 'SGL변동률', 'alu_price',
#        '총자산이익률ROA(%)', 'co_volatility', 'nasdaq', 'nasdaq_거래량', '주당순이익EPS(달러)',
#        'ssec_거래량', 'dollar', 'dollar_volatility', 'carbon_credits', '영업이익',
#        '영업이익률', 'EVE변동률', 'kars_volatility', 'tbx', 'cu_change', 'DRIV종가',
#        'REGI_vol', 'REGI_change', 'snp_500', 'carbon_credits_volatility',
#        'BYD종가', 'kodex_volatility', 'snp_500_volatility', 'tiger_거래량', '매출원가',
#        'tiger_volatility', '순이익', '매출총이익', 'EVE종가', '매출액', 'EVE거래량', 'batt',
#        'tbx_거래량', 'batt_거래량', 'ssec_volatility', 'tbx_volatility', 'alu_vol',
# ...

# %%
'batt_volatility', 'alu_change',
       'li_price', 'co', 'PSI종가', 'SOXX종가', 'ssec', 'SGL종가', 'alu_price',
       '총자산이익률ROA(%)',  'nasdaq', 'nasdaq_거래량', '주당순이익EPS(달러)', 'carbon_credits', '영업이익',
       '영업이익률','tbx', 'cu_change', 'DRIV종가', 'REGI_change', 'snp_500', 'BYD종가'

# %%
'batt_volatility',  'alu_change',
        'LIT거래량', 'SOXX거래량', 'kars_거래량',
       'SOXL거래량', 'ACDC거래량','SGL변동률', 
        'co_volatility', 'ssec_거래량', 'dollar', 'dollar_volatility',
       'EVE변동률', 'kars_volatility',
       'REGI_vol', 'REGI_change','carbon_credits_volatility',

# %%
# ElasticNet

from sklearn.linear_model import ElasticNet

# %%
el= ElasticNet(alpha=13, l1_ratio=0.3)

# %%
el.fit(x_train_scaled, y_train)
preds_el = el.predict(x_test_scaled)
print(el.score(x_train_scaled, y_train))
print(el.score(x_test_scaled, y_test))
# Out:
# 0.9180489025332533
# 0.6124212350333088

# %%
# 13, 0.3

# %%
# GridSearch

from sklearn.model_selection import GridSearchCV

ell = ElasticNet()

# %%
params = {'alpha' : list(np.arange(0.001, 100, 0.001)), 'l1_ratio' : list(np.arange(0, 1, 0.001))}

# %%
grid = GridSearchCV(ell, param_grid=params, refit = True, verbose = True)

# %%
grid.fit(x_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 99999000 candidates, totalling 499995000 fits

# %%
grid.best_params_
# Out:
# {'alpha': 1, 'l1_ratio': 0.1}

# %%
grid.best_score_
# Out:
# -2.729571873282516

# %%
# r2 score

from sklearn.metrics import r2_score

print(r2_score(y_test, preds_el))
# Out:
# 0.6123973161940368

# %%
preds_el
# Out:
# array([615.06040286, 601.32192233, 608.65487084, 615.80823547,
#        619.43582263, 625.78124157, 632.76075555, 663.87069697,
#        645.79717211, 632.12292384, 641.38484632, 637.67747249,
#        651.09143811, 639.55755325, 661.67257969, 669.20045571,
#        661.99945325, 656.67180528, 655.28390455, 657.81470108,
#        673.16959631, 648.7551971 , 646.65013765, 665.09737045,
#        682.57718117, 690.79153207, 677.18033769, 672.09505301,
#        678.76316165, 682.18402573, 679.69442851, 686.49455528,
#        709.57906118, 692.03723975, 711.03534375, 738.35070774,
#        699.42933558, 732.18809473, 712.0615944 , 724.33844688,
#        696.72229904, 710.0591874 , 735.19837232, 719.99594868,
#        730.40966417, 722.23027225, 702.4530193 , 717.72408339,
#        731.50840114, 728.67675886, 747.15952449, 737.76479087,
#        765.08834729, 755.40238561, 750.93566989, 801.36235177,
#        767.35255582, 759.12835614, 752.23797512, 784.46002737,
# ...

# %%
coef_df.index
# Out:
# Index(['자산총계', 'DRIV종가', 'kodex', 'LIT조정종가', '매출총이익률', 'kars', 'tiger',
#        'SOXL종가', '주가수익배수PER(배)', 'nasdaq', 'carbon_credits', '매출총이익', 'EVE종가',
#        'SGL종가', 'dollar', '희토류가격', 'kodex_거래량', '검색량', 'nasdaq_volatility',
#        'ssec_거래량', 'tesla_거래량', 'BYD변동률', 'li_price', 'LIT거래량',
#        'batt_volatility', 'cu_change', 'ACDC거래량', 'DRIV거래량', 'EVE거래량',
#        'tbx_거래량', 'co_volatility', 'kars_거래량', 'ssec', 'oil_price_volatility',
#        'SOXX거래량', 'REGI_change', 'alu_change', '순이익', '영업이익', '매출액',
#        'kodex_volatility', '총자산이익률ROA(%)', 'SOXX종가', 'batt', 'tbx_volatility',
#        'EVE변동률', 'carbon_credits_volatility', 'dollar_volatility', '매출원가',
#        'SGL변동률', 'snp_500_volatility', 'batt_거래량', 'alu_vol',
#        'ssec_volatility', 'REGI_vol', 'nasdaq_거래량', 'SOXL거래량',
#        'tiger_volatility', 'PSI거래량', 'oil_price', 'tiger_거래량', 'tbx',
#        'kars_volatility', 'REGI_price', 'BYD거래량', 'co', 'PSI종가', 'ACDC종가',
# ...
