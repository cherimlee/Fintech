# %%
# matplotlib - 기본
# seaborn
# plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# matplotlib 한글화

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %% [markdown]
# # Line chart
# ---
# - 데이터의 추세를 확인
# - plot()

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]

plt.plot(x,y)

# %%
x = [1,2,3,4,5]
y = [i**2 for i in x]

x1 = [1,2,3,4,5]
y1 = [6,7,8,9,10]

plt.plot(x,y)
plt.plot(x1,y1)

# 그래프를 jpg파일로 저장하기
plt.savefig('text_vis.jpg')

# %%
# 코사인함수
x1 = range(50)
y1 = [np.cos(value) for value in x1]

# 사인함수
x2 = range(50)
y2 = [np.sin(value) for value in x2]

plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
# 출력 사이즈 조절
plt.figure(figsize = (10,5))

# 출력을 1행 2열로 나눠서 첫번째에 출력
plt.subplot(1,2,1)
# 컬러와 라인스타일 변경 가능
plt.plot(x1,y1, color = 'red', linestyle = 'dotted')

# 출력을 1행 2열로 나눠서 두번째에 출력
plt.subplot(1,2,2)
# 컬러와 라인스타일 변경 가능
plt.plot(x2,y2, color = 'blue', linestyle = 'dashed')

# %%
x1 = range(100)
y1 = [value for value in x1]

x2 = range(100)
y2 = [value+50 for value in x2]

# c: color, rgb코드 입력 가능      ls : linestyle         label : 그래프의 이름
plt.plot(x1,y1, c = '#a52a2a', ls = '-.', label = 'Line1')
plt.plot(x2,y2, c = '#0000ff', ls = ':', label = 'Line2')

# text 넣기  (50,60위치에, 'text')
plt.text(50,60, 'Line 1')

# 화살표(), text(30,110)위치에서 (50,100)을 가르킨다
plt.annotate('Line 2', xytext = (30,110), xy = (50,100), arrowprops = dict(facecolor='yellow', shrink = 0.1))

# label의 범례를 표시(위치값 세팅 , default : 빈공간)
plt.legend(fancybox = True, shadow = True, loc = 'upper right')

# 가로 세로 이름 붙이기
plt.xlabel('X_axis')
plt.ylabel('Y_axis')
# Out:
# Text(0, 0.5, 'Y_axis')

# %% [markdown]
# # Scatter Plot
# ---
# - 데이터의 분포
# - scatter()

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]

plt.scatter(x,y)

# %%
# 0~1까지의 수 중에 난수100개
x = np.random.rand(100)

# 표준정규분포 중 난수 100개 / 10
y = x + np.random.randn(100)/10

plt.scatter(x,y)

# %%
x = np.random.rand(500)
y = x + np.random.randn(500)/10

plt.scatter(x,y)

# %%
# 512 by 2
data1 = np.random.rand(512,2)
data2 = np.random.rand(512,2)

# %%
# data1의 [:,0]을 x축, [:,1]을 y축, color = blue, marker = 'x'
plt.scatter(data1[:,0],data1[:,1],c='b', marker='x')
# data2의 [:,0]을 x축, [:,1]을 y축, color = red, marker = 'o'
plt.scatter(data2[:,0],data2[:,1],c='r', marker='o')

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

colors = np.random.rand(n)

# random 면적
area = np.pi * (30 * np.random.rand(n))**2

# s = size,    alpha = 투명도
plt.scatter(x,y, c=colors, s=area, alpha = 0.5)
# 이미지 저장
plt.savefig('text_img.jpg')

# %% [markdown]
# # Bar Plot
# ---
# - 데이터의 크기 비교
# - bar()

# %%
data = np.array([[5,25,50,20],[4,23,51,17],[6,22,52,19]])
x = np.arange(0,8,2)

# %%
data
# Out:
# array([[ 5, 25, 50, 20],
#        [ 4, 23, 51, 17],
#        [ 6, 22, 52, 19]])

# %%
# x = [0,2,4,6]
x = np.array([0,2,4,6])

# %%
y = data[0]
y
# Out:
# array([ 5, 25, 50, 20])

# %%
plt.bar(x,y, color= 'b', width = 0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x,data[0], color= 'b', width = 0.5)

# data[0]뒤에 data[1]그래프를 그려라
plt.bar(x,data[1], color= 'g', width = 0.5, bottom=np.sum(data[:0], axis=0))
# data[0] + data[1] 합친거 뒤에 data[2]그래프를 그려라
plt.bar(x,data[2], color= 'r', width = 0.5, bottom=np.sum(data[:1], axis=0))
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x, data[0], color='b', width=0.5)
# 가로축 방향으로 0.5만큼 이동해서 그래프 그리기
# x가 np.array일 경우 그냥 덧샘
# x가 list일 경우 더할 값을 리스트 * len(x)로 바꿔주기
plt.bar(x+0.5, data[1], color='g', width=0.5)
plt.bar(x+1, data[2], color='r', width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Histogram
# ---
# - 빈도 : 구간의 데이터 수를 나타내고자 할 때
# - hist()

# %%
x = np.random.randn(1000)

# bins : 구간 갯수
plt.hist(x, bins = 20)

# jupyter환경에서는 show()를 안해도 된다
plt.show()

# %% [markdown]
# # Box plot
# ---
# - 데이터 분포를 표현
# - boxplot()

# %%
data = np.random.randn(100,5)
data[:5]
# Out:
# array([[ 0.6194265 ,  0.10998228, -0.53662014, -0.25781178,  0.15834544],
#        [-0.68665856,  0.06014422,  0.1650256 ,  0.15736066,  2.25641177],
#        [ 1.49035678, -0.36666756, -2.24134751, -0.22722258, -0.23302072],
#        [ 1.0629618 ,  0.93645108,  0.98730216,  0.75638022, -0.997969  ],
#        [-0.2781685 ,  1.16857147,  0.72017689, -0.76864572,  0.02117932]])

# %%
plt.boxplot(data)

# box가 작을수록 데이터의 흩어짐이 적다
# 박스의 일정 범위 밖으로 나간 데이터 : outlier

# 최대값
# 상위 75% : 제 3사분위 수 (Q3)
# 주황색 선 :  제 2사분위 수 또는 중위수 (Q2)
# 하위 25% : 제 1사분위 수 (Q1)
# 최소값

plt.show()

# %% [markdown]
# # Pandas Visualization

# %%
# plt.figure() - 도화지

# plt.plot() - 그래프

# plt.show() - 화면에 출력

# %%
plt.figure(figsize=(10,5))

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drinks = pd.read_csv(url)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.columns = ['country', 'beer', 'spirit', 'wine', 'litres', 'continent']
drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
df = drinks.copy()

# %%
df.head()
# Out:
#        country  beer  spirit  wine  litres continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
# df의 인덱스를 'country'로 변경 = df.set_index[0]
df = df.set_index('country')
df.head()
# Out:
#              beer  spirit  wine  litres continent
# country
# Afghanistan     0       0     0     0.0        AS
# Albania        89     132    54     4.9        EU
# Algeria        25       0    14     0.7        AF
# Andorra       245     138   312    12.4        EU
# Angola        217      57    45     5.9        AF

# %%
# 기본 line chart
df.beer.plot()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
plt.figure(figsize = (15,3))
# 'beer'을 기준으로 정렬 후 'beer'의 row값을 출력
df.sort_values('beer')['beer'].plot()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
# bar 차트
plt.figure(figsize = (15,3))
df.beer.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
plt.figure(figsize = (15,3))
# beer을 내림차순 정렬 후 상위 20개만 bar차트로 출력
df.beer.sort_values(ascending=False)[:20].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
# 대륙별 음료 평균소비량
df.groupby('continent').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
# stacked : 겹쳐서
df.groupby('continent').mean().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='continent'>

# %% [markdown]
# ## histogram

# %%
# 맥주를 많이 먹는 빈도수(0에 가까운 국가가 많다)
df['beer'].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## scatter

# %%
# 전반적으로 와인소비량에 비해 맥주 소비량이 높다.
df.plot(x='beer',y='wine',kind='scatter')
# Out:
# <AxesSubplot:xlabel='beer', ylabel='wine'>

# %%
# .plotting.scatter_matrix : 모든 데이터(float로 구성된 데이터)간의 상관관계를 scatter로 보여준다
pd.plotting.scatter_matrix(df)
plt.show()

# %% [markdown]
# ## boxplot

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## matshow()

# %%
# 칼럼간의 상관계수를 나타내준다
df.corr()
# Out:
#             beer    spirit      wine    litres
# beer    1.000000  0.458819  0.527172  0.835839
# spirit  0.458819  1.000000  0.194797  0.654968
# wine    0.527172  0.194797  1.000000  0.667598
# litres  0.835839  0.654968  0.667598  1.000000

# %%
# 색이 밝을 수록 상관관계가 높다
plt.matshow(df.corr())

# %% [markdown]
# ## Seaporn

# %%
import seaborn as sns

# %%
x =
# Out:
#   File "C:\Users\bitcamp\AppData\Local\Temp/ipykernel_8900/3306000817.py", line 1
#     x =
#         ^
# SyntaxError: invalid syntax

# %% [raw]
# tips.info()

# %%
tips = sns.load_dataset("tips")

# %%
# bar plot

# %%
sns.barplot(x='day', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# box plot

# %%
sns.boxplot(x='day',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# countplot()

# %%
sns.countplot('sex', data=tips)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8900/316169179.py in <module>
#       1 sns.countplot('sex', data=tips)
# ----> 2 plt.show
#
# NameError: name 'plt' is not defined

# %%
# regression plot

# %%
sns.regplot(x='total_bill', y='tip', data = tips)
# Out:
#   File "C:\Users\bitcamp\AppData\Local\Temp/ipykernel_8900/2527450719.py", line 1
#     sns.regplot(x='total_bill', y='tip', data = tips. hue = 'sex')
#                                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Plotly

# %%
sns.Implot(x="total_bill", y='tip', data=tips, hue = "sex")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8900/414514175.py in <module>
# ----> 1 sns.Implot(x="total_bill", y='tip', data=tips, hue = "sex")
#
# AttributeError: module 'seaborn' has no attribute 'Implot'

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_table = flights.pivot('month','year', 'passengers')
flights_table
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights_table)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
# plotly
