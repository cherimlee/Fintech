# %%
# https://www.data.go.kr/dataset/15012005/fileData.do

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_csv("./data/소상공인시장진흥공단_상가(상권)정보_20210930/소상공인시장진흥공단_상가(상권)정보_서울_202109.csv")
df
# Out:
#           상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0       22767534       BYC상신점  상신점         D       소매       D05       의복의류
# 1       23324279        제중건강원  NaN         D       소매       D10    건강/미용식품
# 2       24525909        민속악기사  NaN         D       소매       D04  취미/오락관련소매
# 3       17174119         쓰리에프  NaN         Q       음식       Q01         한식
# 4       17174096           채움  NaN         Q       음식       Q01         한식
# ...          ...          ...  ...       ...      ...       ...        ...
# 325875  17696078  엘케이공인중개사사무소  NaN         L      부동산       L01      부동산중개
# 325876  17697616         봄쥬얼리  NaN         D       소매       D26   시계/귀금속소매
# 325877  17711133        아이디어뱅  NaN         D       소매       D09   애견/애완/동물
# 325878  17717332        애프터아트  NaN         Q       음식       Q12     커피점/카페
# 325879  17710502         허브헤어  NaN         F    생활서비스       F01    이/미용/건강
#
#        상권업종소분류코드      상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0         D05A07      셔츠/내의/속옷      NaN  ...  1171011300100360000022458
# 1         D10A07           건강원   G47216  ...  1156010600100410002034626
# 2         D04A09          악기판매   G47593  ...  1120012200101420011000227
# 3         Q01A01     한식/백반/한정식   I56111  ...  1159010700101390073009536
# 4         Q01A01     한식/백반/한정식   I56111  ...  1111012400100580000017956
# ...          ...           ...      ...  ...                        ...
# 325875    L01A01         부동산중개   L68221  ...  1144012300104830022015270
# 325876    D26A01        시계/귀금속   G47830  ...  1138010200100210134000001
# 325877    D09A01  애견/애완/동물사육판매   G47852  ...  1138010900102370095012098
# 325878    Q12A01   커피전문점/카페/다방   I56220  ...  1121510100101300009023366
# 325879    F01A01         여성미용실   S96112  ...  1130510300104820032012137
#
#              건물명                    도로명주소   구우편번호   신우편번호  동정보  층정보   호정보  \
# 0           성암빌딩        서울특별시 송파구 오금로 527  138110  5768.0  NaN    1   NaN
# 1            NaN  서울특별시 영등포구 영중로14길 11-17  150035  7250.0  NaN    1   NaN
# 2            NaN         서울특별시 성동구 용답5길 2  133849  4803.0  NaN  NaN   NaN
# 3            NaN    서울특별시 동작구 동작대로27가길 12  156816  7008.0  NaN  NaN   NaN
# 4       두산위브파빌리온         서울특별시 종로구 삼봉로 81  110858  3150.0  NaN  NaN   NaN
# ...          ...                      ...     ...     ...  ...  ...   ...
# 325875       NaN         서울특별시 마포구 망원로 95  121827  3964.0  NaN    1   NaN
# 325876   래미안베라힐즈        서울특별시 은평구 통일로 630  122020  3372.0  203  NaN  1405
# 325877       NaN   서울특별시 은평구 가좌로11가길 21-6  122888  3439.0  NaN  NaN   NaN
# 325878      영진빌딩      서울특별시 광진구 용마산로1길 66  143891  4930.0  NaN  NaN   NaN
# 325879       NaN       서울특별시 강북구 삼양로73길 1  142875  1103.0  NaN    1   NaN
#
#                 경도         위도
# 0       127.147321  37.493054
# 1       126.907168  37.520613
# 2       127.049018  37.566857
# 3       126.980952  37.487105
# 4       126.981794  37.572387
# ...            ...        ...
# 325875  126.907290  37.557971
# 325876  126.936049  37.604195
# 325877  126.905613  37.596790
# 325878  127.085023  37.556004
# 325879  127.017622  37.629348
#
# [325880 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325880 entries, 0 to 325879
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     325880 non-null  int64
#  1   상호명        325879 non-null  object
#  2   지점명        59613 non-null   object
#  3   상권업종대분류코드  325880 non-null  object
#  4   상권업종대분류명   325880 non-null  object
#  5   상권업종중분류코드  325880 non-null  object
#  6   상권업종중분류명   325880 non-null  object
#  7   상권업종소분류코드  325880 non-null  object
#  8   상권업종소분류명   325880 non-null  object
#  9   표준산업분류코드   306407 non-null  object
#  10  표준산업분류명    306407 non-null  object
#  11  시도코드       325880 non-null  int64
#  12  시도명        325880 non-null  object
#  13  시군구코드      325880 non-null  int64
#  14  시군구명       325880 non-null  object
#  15  행정동코드      325880 non-null  int64
#  16  행정동명       325235 non-null  object
#  17  법정동코드      325880 non-null  int64
#  18  법정동명       325880 non-null  object
#  19  지번코드       325880 non-null  int64
#  20  대지구분코드     325880 non-null  int64
#  21  대지구분명      325880 non-null  object
#  22  지번본번지      325880 non-null  int64
#  23  지번부번지      260409 non-null  float64
#  24  지번주소       325880 non-null  object
#  25  도로명코드      325880 non-null  int64
#  26  도로명        325880 non-null  object
#  27  건물본번지      325880 non-null  int64
#  28  건물부번지      40995 non-null   float64
#  29  건물관리번호     325880 non-null  object
#  30  건물명        158286 non-null  object
#  31  도로명주소      325880 non-null  object
#  32  구우편번호      325880 non-null  int64
#  33  신우편번호      325875 non-null  float64
#  34  동정보        29108 non-null   object
#  35  층정보        204134 non-null  object
#  36  호정보        65675 non-null   object
#  37  경도         325880 non-null  float64
#  38  위도         325880 non-null  float64
# dtypes: float64(5), int64(11), object(23)
# memory usage: 97.0+ MB

# %%
# 베스킨라빈스 vs 던킨도너츠

# %%
df.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_col = df.isnull().sum() < 1000
use_col = df_col[df_col].index
use_col
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명',
#        '상권업종소분류코드', '상권업종소분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드',
#        '행정동명', '법정동코드', '법정동명', '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번주소',
#        '도로명코드', '도로명', '건물본번지', '건물관리번호', '도로명주소', '구우편번호', '신우편번호', '경도',
#        '위도'],
#       dtype='object')

# %%
df1 = df[use_col].copy()

# %%
df1.시도명.unique()
# Out:
# array(['서울특별시'], dtype=object)

# %%
df1
# Out:
#           상가업소번호          상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0       22767534       BYC상신점         D       소매       D05       의복의류
# 1       23324279        제중건강원         D       소매       D10    건강/미용식품
# 2       24525909        민속악기사         D       소매       D04  취미/오락관련소매
# 3       17174119         쓰리에프         Q       음식       Q01         한식
# 4       17174096           채움         Q       음식       Q01         한식
# ...          ...          ...       ...      ...       ...        ...
# 325875  17696078  엘케이공인중개사사무소         L      부동산       L01      부동산중개
# 325876  17697616         봄쥬얼리         D       소매       D26   시계/귀금속소매
# 325877  17711133        아이디어뱅         D       소매       D09   애견/애완/동물
# 325878  17717332        애프터아트         Q       음식       Q12     커피점/카페
# 325879  17710502         허브헤어         F    생활서비스       F01    이/미용/건강
#
#        상권업종소분류코드      상권업종소분류명  시도코드    시도명  ...                    지번주소  \
# 0         D05A07      셔츠/내의/속옷    11  서울특별시  ...        서울특별시 송파구 거여동 36
# 1         D10A07           건강원    11  서울특별시  ...  서울특별시 영등포구 영등포동5가 41-1
# 2         D04A09          악기판매    11  서울특별시  ...    서울특별시 성동구 용답동 142-11
# 3         Q01A01     한식/백반/한정식    11  서울특별시  ...    서울특별시 동작구 사당동 139-72
# 4         Q01A01     한식/백반/한정식    11  서울특별시  ...        서울특별시 종로구 수송동 58
# ...          ...           ...   ...    ...  ...                     ...
# 325875    L01A01         부동산중개    11  서울특별시  ...    서울특별시 마포구 망원동 483-22
# 325876    D26A01        시계/귀금속    11  서울특별시  ...       서울특별시 은평구 녹번동 283
# 325877    D09A01  애견/애완/동물사육판매    11  서울특별시  ...    서울특별시 은평구 신사동 237-95
# 325878    Q12A01   커피전문점/카페/다방    11  서울특별시  ...     서울특별시 광진구 중곡동 130-9
# 325879    F01A01         여성미용실    11  서울특별시  ...    서울특별시 강북구 수유동 482-32
#
#                도로명코드                 도로명 건물본번지                     건물관리번호  \
# 0       117103123014       서울특별시 송파구 오금로   527  1171011300100360000022458
# 1       115604154799   서울특별시 영등포구 영중로14길    11  1156010600100410002034626
# 2       112004109480      서울특별시 성동구 용답5길     2  1120012200101420011000227
# 3       115904157119  서울특별시 동작구 동작대로27가길    12  1159010700101390073009536
# 4       111103100006       서울특별시 종로구 삼봉로    81  1111012400100580000017956
# ...              ...                 ...   ...                        ...
# 325875  114403113006       서울특별시 마포구 망원로    95  1144012300104830022015270
# 325876  113803000008       서울특별시 은평구 통일로   630  1138010200100210134000001
# 325877  113804133002   서울특별시 은평구 가좌로11가길    21  1138010900102370095012098
# 325878  112154112381    서울특별시 광진구 용마산로1길    66  1121510100101300009023366
# 325879  113054124288    서울특별시 강북구 삼양로73길     1  1130510300104820032012137
#
#                           도로명주소   구우편번호   신우편번호          경도         위도
# 0             서울특별시 송파구 오금로 527  138110  5768.0  127.147321  37.493054
# 1       서울특별시 영등포구 영중로14길 11-17  150035  7250.0  126.907168  37.520613
# 2              서울특별시 성동구 용답5길 2  133849  4803.0  127.049018  37.566857
# 3         서울특별시 동작구 동작대로27가길 12  156816  7008.0  126.980952  37.487105
# 4              서울특별시 종로구 삼봉로 81  110858  3150.0  126.981794  37.572387
# ...                         ...     ...     ...         ...        ...
# 325875         서울특별시 마포구 망원로 95  121827  3964.0  126.907290  37.557971
# 325876        서울특별시 은평구 통일로 630  122020  3372.0  126.936049  37.604195
# 325877   서울특별시 은평구 가좌로11가길 21-6  122888  3439.0  126.905613  37.596790
# 325878      서울특별시 광진구 용마산로1길 66  143891  4930.0  127.085023  37.556004
# 325879       서울특별시 강북구 삼양로73길 1  142875  1103.0  127.017622  37.629348
#
# [325880 rows x 30 columns]

# %%
# for i in df1.상호명:
#     if '베스킨라빈스' in i:
#         print(i)

# %%
# 베스킨라빈스 매장 데이터 추출

# %%
 # df1.상호명 == '베스킨라빈스'  # 영문이름으로 들어가 있을 수도 있음 ㄷㄷ

# %%
# df1['상호명'].str.contains('베스킨라빈스')     # for문 안쓰고 쓸 수 있는 메소드
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 325875    False
# 325876    False
# 325877    False
# 325878    False
# 325879    False
# Name: 상호명, Length: 325880, dtype: object

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#           상가업소번호          상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0       22767534       BYC상신점         D       소매       D05       의복의류
# 1       23324279        제중건강원         D       소매       D10    건강/미용식품
# 2       24525909        민속악기사         D       소매       D04  취미/오락관련소매
# 3       17174119         쓰리에프         Q       음식       Q01         한식
# 4       17174096           채움         Q       음식       Q01         한식
# ...          ...          ...       ...      ...       ...        ...
# 325875  17696078  엘케이공인중개사사무소         L      부동산       L01      부동산중개
# 325876  17697616         봄쥬얼리         D       소매       D26   시계/귀금속소매
# 325877  17711133        아이디어뱅         D       소매       D09   애견/애완/동물
# 325878  17717332        애프터아트         Q       음식       Q12     커피점/카페
# 325879  17710502         허브헤어         F    생활서비스       F01    이/미용/건강
#
#        상권업종소분류코드      상권업종소분류명  시도코드    시도명  ...                    지번주소  \
# 0         D05A07      셔츠/내의/속옷    11  서울특별시  ...        서울특별시 송파구 거여동 36
# 1         D10A07           건강원    11  서울특별시  ...  서울특별시 영등포구 영등포동5가 41-1
# 2         D04A09          악기판매    11  서울특별시  ...    서울특별시 성동구 용답동 142-11
# 3         Q01A01     한식/백반/한정식    11  서울특별시  ...    서울특별시 동작구 사당동 139-72
# 4         Q01A01     한식/백반/한정식    11  서울특별시  ...        서울특별시 종로구 수송동 58
# ...          ...           ...   ...    ...  ...                     ...
# 325875    L01A01         부동산중개    11  서울특별시  ...    서울특별시 마포구 망원동 483-22
# 325876    D26A01        시계/귀금속    11  서울특별시  ...       서울특별시 은평구 녹번동 283
# 325877    D09A01  애견/애완/동물사육판매    11  서울특별시  ...    서울특별시 은평구 신사동 237-95
# 325878    Q12A01   커피전문점/카페/다방    11  서울특별시  ...     서울특별시 광진구 중곡동 130-9
# 325879    F01A01         여성미용실    11  서울특별시  ...    서울특별시 강북구 수유동 482-32
#
#                도로명코드                 도로명 건물본번지                     건물관리번호  \
# 0       117103123014       서울특별시 송파구 오금로   527  1171011300100360000022458
# 1       115604154799   서울특별시 영등포구 영중로14길    11  1156010600100410002034626
# 2       112004109480      서울특별시 성동구 용답5길     2  1120012200101420011000227
# 3       115904157119  서울특별시 동작구 동작대로27가길    12  1159010700101390073009536
# 4       111103100006       서울특별시 종로구 삼봉로    81  1111012400100580000017956
# ...              ...                 ...   ...                        ...
# 325875  114403113006       서울특별시 마포구 망원로    95  1144012300104830022015270
# 325876  113803000008       서울특별시 은평구 통일로   630  1138010200100210134000001
# 325877  113804133002   서울특별시 은평구 가좌로11가길    21  1138010900102370095012098
# 325878  112154112381    서울특별시 광진구 용마산로1길    66  1121510100101300009023366
# 325879  113054124288    서울특별시 강북구 삼양로73길     1  1130510300104820032012137
#
#                           도로명주소   구우편번호   신우편번호          경도         위도
# 0             서울특별시 송파구 오금로 527  138110  5768.0  127.147321  37.493054
# 1       서울특별시 영등포구 영중로14길 11-17  150035  7250.0  126.907168  37.520613
# 2              서울특별시 성동구 용답5길 2  133849  4803.0  127.049018  37.566857
# 3         서울특별시 동작구 동작대로27가길 12  156816  7008.0  126.980952  37.487105
# 4              서울특별시 종로구 삼봉로 81  110858  3150.0  126.981794  37.572387
# ...                         ...     ...     ...         ...        ...
# 325875         서울특별시 마포구 망원로 95  121827  3964.0  126.907290  37.557971
# 325876        서울특별시 은평구 통일로 630  122020  3372.0  126.936049  37.604195
# 325877   서울특별시 은평구 가좌로11가길 21-6  122888  3439.0  126.905613  37.596790
# 325878      서울특별시 광진구 용마산로1길 66  143891  4930.0  127.085023  37.556004
# 325879       서울특별시 강북구 삼양로73길 1  142875  1103.0  127.017622  37.629348
#
# [325229 rows x 30 columns]

# %%
df1[df1['상호명'].str.contains('(베|배)스킨라빈스|baskinrobbins')]
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_13924/1730770739.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df1[df1['상호명'].str.contains('(베|배)스킨라빈스|baskinrobbins')]
#           상가업소번호           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 516     20529229     배스킨라빈스공릉점         Q       음식       Q07    패스트푸드
# 2451    23390558    배스킨라빈스강남중앙         Q       음식       Q07    패스트푸드
# 4320    25896019      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 5386    25817917  배스킨라빈스31상봉역점         Q       음식       Q07    패스트푸드
# 5569    25868615   배스킨라빈스31서초점         Q       음식       Q07    패스트푸드
# ...          ...           ...       ...      ...       ...      ...
# 298196  17594947      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 314027  17456023        베스킨라빈스         Q       음식       Q08  제과제빵떡케익
# 316769  17250469      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 320696  17534074        배스킨라빈스         Q       음식       Q07    패스트푸드
# 322331  17508161        배스킨라빈스         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드 상권업종소분류명  시도코드    시도명  ...                   지번주소  \
# 516       Q07A07  아이스크림판매    11  서울특별시  ...    서울특별시 노원구 공릉동 208-5
# 2451      Q07A07  아이스크림판매    11  서울특별시  ...   서울특별시 강남구 역삼동 817-11
# 4320      Q07A07  아이스크림판매    11  서울특별시  ...   서울특별시 강서구 등촌동 639-11
# 5386      Q07A07  아이스크림판매    11  서울특별시  ...    서울특별시 중랑구 상봉동 115-1
# 5569      Q07A07  아이스크림판매    11  서울특별시  ...  서울특별시 서초구 방배동 1001-31
# ...          ...      ...   ...    ...  ...                    ...
# 298196    Q07A07  아이스크림판매    11  서울특별시  ...   서울특별시 강남구 수서동 595-18
# 314027    Q08A01      제과점    11  서울특별시  ...   서울특별시 구로구 구로동 141-14
# 316769    Q07A07  아이스크림판매    11  서울특별시  ...      서울특별시 용산구 효창동 287
# 320696    Q07A07  아이스크림판매    11  서울특별시  ...      서울특별시 강남구 세곡동 586
# 322331    Q07A07  아이스크림판매    11  서울특별시  ...    서울특별시 송파구 잠실동 182-6
#
#                도로명코드                도로명 건물본번지                     건물관리번호  \
# 516     113503005050      서울특별시 노원구 공릉로   198  1135010300102080005014429
# 2451    116804166038  서울특별시 강남구 강남대로96길     9  1168010100108170011023756
# 4320    115003005069      서울특별시 강서구 화곡로   398  1150010200106390011027411
# 5386    112603005027      서울특별시 중랑구 면목로   495  1126010200101150001016299
# 5569    116503121021      서울특별시 서초구 효령로   186  1165010100110010031021257
# ...              ...                ...   ...                        ...
# 298196  116803122002      서울특별시 강남구 광평로   196  1168011500105950000000001
# 314027  115303116010      서울특별시 구로구 도림로    75  1153010200101410005016910
# 316769  111703005016      서울특별시 용산구 백범로   313  1117011900100130002000001
# 320696  116804166875  서울특별시 강남구 헌릉로569길     3  1168011100105860000000001
# 322331  117104169204  서울특별시 송파구 백제고분로7길    29  1171010100101820006000575
#
#                        도로명주소   구우편번호   신우편번호          경도         위도
# 516        서울특별시 노원구 공릉로 198  139240  1814.0  127.078586  37.627425
# 2451     서울특별시 강남구 강남대로96길 9  135080  6129.0  127.027724  37.499852
# 4320       서울특별시 강서구 화곡로 398  157030  7567.0  126.854800  37.558456
# 5386       서울특별시 중랑구 면목로 495  131220  2137.0  127.085303  37.596040
# 5569       서울특별시 서초구 효령로 186  137060  6707.0  127.004329  37.482474
# ...                      ...     ...     ...         ...        ...
# 298196     서울특별시 강남구 광평로 196  135239  6362.0  127.094258  37.484000
# 314027      서울특별시 구로구 도림로 75  152846  8312.0  126.891693  37.489986
# 316769     서울특별시 용산구 백범로 313  140120  4317.0  126.962964  37.539236
# 320696   서울특별시 강남구 헌릉로569길 3  135190  6376.0  127.101316  37.466798
# 322331  서울특별시 송파구 백제고분로7길 29  138861  5557.0  127.082147  37.510893
#
# [352 rows x 30 columns]

# %%
df31 = df1[df1['상호명'].str.contains('(베|배)스킨라빈스|baskinrobbins')]
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_13924/143537280.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df31 = df1[df1['상호명'].str.contains('(베|배)스킨라빈스|baskinrobbins')]

# %%
df31
# Out:
#           상가업소번호           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 516     20529229     배스킨라빈스공릉점         Q       음식       Q07    패스트푸드
# 2451    23390558    배스킨라빈스강남중앙         Q       음식       Q07    패스트푸드
# 4320    25896019      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 5386    25817917  배스킨라빈스31상봉역점         Q       음식       Q07    패스트푸드
# 5569    25868615   배스킨라빈스31서초점         Q       음식       Q07    패스트푸드
# ...          ...           ...       ...      ...       ...      ...
# 298196  17594947      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 314027  17456023        베스킨라빈스         Q       음식       Q08  제과제빵떡케익
# 316769  17250469      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 320696  17534074        배스킨라빈스         Q       음식       Q07    패스트푸드
# 322331  17508161        배스킨라빈스         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드 상권업종소분류명  시도코드    시도명  ...                   지번주소  \
# 516       Q07A07  아이스크림판매    11  서울특별시  ...    서울특별시 노원구 공릉동 208-5
# 2451      Q07A07  아이스크림판매    11  서울특별시  ...   서울특별시 강남구 역삼동 817-11
# 4320      Q07A07  아이스크림판매    11  서울특별시  ...   서울특별시 강서구 등촌동 639-11
# 5386      Q07A07  아이스크림판매    11  서울특별시  ...    서울특별시 중랑구 상봉동 115-1
# 5569      Q07A07  아이스크림판매    11  서울특별시  ...  서울특별시 서초구 방배동 1001-31
# ...          ...      ...   ...    ...  ...                    ...
# 298196    Q07A07  아이스크림판매    11  서울특별시  ...   서울특별시 강남구 수서동 595-18
# 314027    Q08A01      제과점    11  서울특별시  ...   서울특별시 구로구 구로동 141-14
# 316769    Q07A07  아이스크림판매    11  서울특별시  ...      서울특별시 용산구 효창동 287
# 320696    Q07A07  아이스크림판매    11  서울특별시  ...      서울특별시 강남구 세곡동 586
# 322331    Q07A07  아이스크림판매    11  서울특별시  ...    서울특별시 송파구 잠실동 182-6
#
#                도로명코드                도로명 건물본번지                     건물관리번호  \
# 516     113503005050      서울특별시 노원구 공릉로   198  1135010300102080005014429
# 2451    116804166038  서울특별시 강남구 강남대로96길     9  1168010100108170011023756
# 4320    115003005069      서울특별시 강서구 화곡로   398  1150010200106390011027411
# 5386    112603005027      서울특별시 중랑구 면목로   495  1126010200101150001016299
# 5569    116503121021      서울특별시 서초구 효령로   186  1165010100110010031021257
# ...              ...                ...   ...                        ...
# 298196  116803122002      서울특별시 강남구 광평로   196  1168011500105950000000001
# 314027  115303116010      서울특별시 구로구 도림로    75  1153010200101410005016910
# 316769  111703005016      서울특별시 용산구 백범로   313  1117011900100130002000001
# 320696  116804166875  서울특별시 강남구 헌릉로569길     3  1168011100105860000000001
# 322331  117104169204  서울특별시 송파구 백제고분로7길    29  1171010100101820006000575
#
#                        도로명주소   구우편번호   신우편번호          경도         위도
# 516        서울특별시 노원구 공릉로 198  139240  1814.0  127.078586  37.627425
# 2451     서울특별시 강남구 강남대로96길 9  135080  6129.0  127.027724  37.499852
# 4320       서울특별시 강서구 화곡로 398  157030  7567.0  126.854800  37.558456
# 5386       서울특별시 중랑구 면목로 495  131220  2137.0  127.085303  37.596040
# 5569       서울특별시 서초구 효령로 186  137060  6707.0  127.004329  37.482474
# ...                      ...     ...     ...         ...        ...
# 298196     서울특별시 강남구 광평로 196  135239  6362.0  127.094258  37.484000
# 314027      서울특별시 구로구 도림로 75  152846  8312.0  126.891693  37.489986
# 316769     서울특별시 용산구 백범로 313  140120  4317.0  126.962964  37.539236
# 320696   서울특별시 강남구 헌릉로569길 3  135190  6376.0  127.101316  37.466798
# 322331  서울특별시 송파구 백제고분로7길 29  138861  5557.0  127.082147  37.510893
#
# [352 rows x 30 columns]

# %%
df1['상호명'] == ' 베스킨라빈스'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 325875    False
# 325876    False
# 325877    False
# 325878    False
# 325879    False
# Name: 상호명, Length: 325229, dtype: bool

# %%
df31.columns.unique()
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명',
#        '상권업종소분류코드', '상권업종소분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드',
#        '행정동명', '법정동코드', '법정동명', '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번주소',
#        '도로명코드', '도로명', '건물본번지', '건물관리번호', '도로명주소', '구우편번호', '신우편번호', '경도',
#        '위도'],
#       dtype='object')

# %%
# df1['상호명'] = df['상호명'].apply(lambda x : x.lower())

# %%
df31.상권업종대분류명.unique()
# Out:
# array(['음식', '소매'], dtype=object)

# %%
df31.drop(df31[df31.상권업종대분류명 == '소매'].index, inplace=True)
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df31.상권업종대분류명.unique()
# Out:
# array(['음식'], dtype=object)

# %%
# 던킨도넛 데이터 추출

# %%
dfdunk=df1[df1['상호명'].str.contains('던킨도너츠|dunkindonuts')]

# %%
# 매장 수

# %%
len(df31)
# Out:
# 351

# %%
len(dfdunk)
# Out:
# 96

# %%
# 각각 어느 구에 매장 수가 많은지 비교

# %%
df31.groupby("시군구명").상호명.count().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='시군구명'>

# %%
dfdunk.groupby("시군구명").상호명.count().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='시군구명'>

# %%
# 위치를 그래프로 
df31[['위도','경도']].plot(kind='scatter',x='경도', y='위도')
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
dfdunk[['위도','경도']].plot(kind='scatter',x='경도', y='위도')
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
df31['상호이름'] = '베스킨'
dfdunk['상호이름'] = '던킨'
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_13924/1353195403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df31['상호이름'] = '베스킨'
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_13924/1353195403.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdunk['상호이름'] = '던킨'

# %%
df_con = pd.concat([df31, dfdunk])

# %%
df_con
# Out:
#           상가업소번호           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 516     20529229     배스킨라빈스공릉점         Q       음식       Q07    패스트푸드
# 2451    23390558    배스킨라빈스강남중앙         Q       음식       Q07    패스트푸드
# 4320    25896019      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 5386    25817917  배스킨라빈스31상봉역점         Q       음식       Q07    패스트푸드
# 5569    25868615   배스킨라빈스31서초점         Q       음식       Q07    패스트푸드
# ...          ...           ...       ...      ...       ...      ...
# 278417  20674363         던킨도너츠         Q       음식       Q07    패스트푸드
# 280257  20304915    던킨도너츠창동하나로         Q       음식       Q07    패스트푸드
# 282962  19983532   던킨도너츠올림픽공원점         Q       음식       Q07    패스트푸드
# 284662  20594624         던킨도너츠         Q       음식       Q07    패스트푸드
# 285282  20389245         던킨도너츠         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드 상권업종소분류명  시도코드    시도명  ...         도로명코드                도로명  \
# 516       Q07A07  아이스크림판매    11  서울특별시  ...  113503005050      서울특별시 노원구 공릉로
# 2451      Q07A07  아이스크림판매    11  서울특별시  ...  116804166038  서울특별시 강남구 강남대로96길
# 4320      Q07A07  아이스크림판매    11  서울특별시  ...  115003005069      서울특별시 강서구 화곡로
# 5386      Q07A07  아이스크림판매    11  서울특별시  ...  112603005027      서울특별시 중랑구 면목로
# 5569      Q07A07  아이스크림판매    11  서울특별시  ...  116503121021      서울특별시 서초구 효령로
# ...          ...      ...   ...    ...  ...           ...                ...
# 278417    Q07A06    도너츠전문    11  서울특별시  ...  112302000008    서울특별시 동대문구 천호대로
# 280257    Q07A06    도너츠전문    11  서울특별시  ...  113204127201   서울특별시 도봉구 마들로11길
# 282962    Q07A06    도너츠전문    11  서울특별시  ...  117103123023     서울특별시 송파구 올림픽로
# 284662    Q07A06    도너츠전문    11  서울특별시  ...  115904157499     서울특별시 동작구 알마타길
# 285282    Q07A06    도너츠전문    11  서울특별시  ...  114403113014      서울특별시 마포구 양화로
#
#         건물본번지                     건물관리번호                도로명주소   구우편번호   신우편번호  \
# 516       198  1135010300102080005014429    서울특별시 노원구 공릉로 198  139240  1814.0
# 2451        9  1168010100108170011023756  서울특별시 강남구 강남대로96길 9  135080  6129.0
# 4320      398  1150010200106390011027411    서울특별시 강서구 화곡로 398  157030  7567.0
# 5386      495  1126010200101150001016299    서울특별시 중랑구 면목로 495  131220  2137.0
# 5569      186  1165010100110010031021257    서울특별시 서초구 효령로 186  137060  6707.0
# ...       ...                        ...                  ...     ...     ...
# 278417    133  1123010200100330001039028  서울특별시 동대문구 천호대로 133  130817  2565.0
# 280257     20  1132010700100010010014524  서울특별시 도봉구 마들로11길 20  132720  1413.0
# 282962    378  1171011100100400006015853   서울특별시 송파구 올림픽로 378  138050  5544.0
# 284662      6  1159010800103540001000001     서울특별시 동작구 알마타길 6  156808  6941.0
# 285282    157  1144012100101590006022657    서울특별시 마포구 양화로 157  121898  3995.0
#
#                 경도         위도  상호이름
# 516     127.078586  37.627425   베스킨
# 2451    127.027724  37.499852   베스킨
# 4320    126.854800  37.558456   베스킨
# 5386    127.085303  37.596040   베스킨
# 5569    127.004329  37.482474   베스킨
# ...            ...        ...   ...
# 278417  127.038754  37.574540    던킨
# 280257  127.050818  37.655101    던킨
# 282962  127.112129  37.516970    던킨
# 284662  126.924959  37.509801    던킨
# 285282  126.922928  37.556682    던킨
#
# [447 rows x 31 columns]

# %%
df_con
# Out:
#           상가업소번호           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 516     20529229     배스킨라빈스공릉점         Q       음식       Q07    패스트푸드
# 2451    23390558    배스킨라빈스강남중앙         Q       음식       Q07    패스트푸드
# 4320    25896019      배스킨라빈스31         Q       음식       Q07    패스트푸드
# 5386    25817917  배스킨라빈스31상봉역점         Q       음식       Q07    패스트푸드
# 5569    25868615   배스킨라빈스31서초점         Q       음식       Q07    패스트푸드
# ...          ...           ...       ...      ...       ...      ...
# 278417  20674363         던킨도너츠         Q       음식       Q07    패스트푸드
# 280257  20304915    던킨도너츠창동하나로         Q       음식       Q07    패스트푸드
# 282962  19983532   던킨도너츠올림픽공원점         Q       음식       Q07    패스트푸드
# 284662  20594624         던킨도너츠         Q       음식       Q07    패스트푸드
# 285282  20389245         던킨도너츠         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드 상권업종소분류명  시도코드    시도명  ...         도로명코드                도로명  \
# 516       Q07A07  아이스크림판매    11  서울특별시  ...  113503005050      서울특별시 노원구 공릉로
# 2451      Q07A07  아이스크림판매    11  서울특별시  ...  116804166038  서울특별시 강남구 강남대로96길
# 4320      Q07A07  아이스크림판매    11  서울특별시  ...  115003005069      서울특별시 강서구 화곡로
# 5386      Q07A07  아이스크림판매    11  서울특별시  ...  112603005027      서울특별시 중랑구 면목로
# 5569      Q07A07  아이스크림판매    11  서울특별시  ...  116503121021      서울특별시 서초구 효령로
# ...          ...      ...   ...    ...  ...           ...                ...
# 278417    Q07A06    도너츠전문    11  서울특별시  ...  112302000008    서울특별시 동대문구 천호대로
# 280257    Q07A06    도너츠전문    11  서울특별시  ...  113204127201   서울특별시 도봉구 마들로11길
# 282962    Q07A06    도너츠전문    11  서울특별시  ...  117103123023     서울특별시 송파구 올림픽로
# 284662    Q07A06    도너츠전문    11  서울특별시  ...  115904157499     서울특별시 동작구 알마타길
# 285282    Q07A06    도너츠전문    11  서울특별시  ...  114403113014      서울특별시 마포구 양화로
#
#         건물본번지                     건물관리번호                도로명주소   구우편번호   신우편번호  \
# 516       198  1135010300102080005014429    서울특별시 노원구 공릉로 198  139240  1814.0
# 2451        9  1168010100108170011023756  서울특별시 강남구 강남대로96길 9  135080  6129.0
# 4320      398  1150010200106390011027411    서울특별시 강서구 화곡로 398  157030  7567.0
# 5386      495  1126010200101150001016299    서울특별시 중랑구 면목로 495  131220  2137.0
# 5569      186  1165010100110010031021257    서울특별시 서초구 효령로 186  137060  6707.0
# ...       ...                        ...                  ...     ...     ...
# 278417    133  1123010200100330001039028  서울특별시 동대문구 천호대로 133  130817  2565.0
# 280257     20  1132010700100010010014524  서울특별시 도봉구 마들로11길 20  132720  1413.0
# 282962    378  1171011100100400006015853   서울특별시 송파구 올림픽로 378  138050  5544.0
# 284662      6  1159010800103540001000001     서울특별시 동작구 알마타길 6  156808  6941.0
# 285282    157  1144012100101590006022657    서울특별시 마포구 양화로 157  121898  3995.0
#
#                 경도         위도  상호이름
# 516     127.078586  37.627425   베스킨
# 2451    127.027724  37.499852   베스킨
# 4320    126.854800  37.558456   베스킨
# 5386    127.085303  37.596040   베스킨
# 5569    127.004329  37.482474   베스킨
# ...            ...        ...   ...
# 278417  127.038754  37.574540    던킨
# 280257  127.050818  37.655101    던킨
# 282962  127.112129  37.516970    던킨
# 284662  126.924959  37.509801    던킨
# 285282  126.922928  37.556682    던킨
#
# [447 rows x 31 columns]

# %%
df_con [['위도','경도']].plot(kind='scatter',x='경도', y='위도')
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
sns.scatterplot(data=df_con, x ='위도',y = '경도', hue = '상호이름')
# Out:
# <AxesSubplot:xlabel='위도', ylabel='경도'>

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\bitcamp\anaconda3\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in c:\users\bitcamp\anaconda3\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: branca>=0.3.0 in c:\users\bitcamp\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\bitcamp\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\bitcamp\anaconda3\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bitcamp\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bitcamp\anaconda3\lib\site-packages (from requests->folium) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bitcamp\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bitcamp\anaconda3\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bitcamp\anaconda3\lib\site-packages (from requests->folium) (2.0.4)

# %%
import folium

# %%
lat = df_con['위도'].mean()
long = df_con['경도'].mean()

# %%
folium.Map([lat, long])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_66a82479cc65444cbb58d2efc85d8df5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_66a82479cc65444cbb58d2efc85d8df5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_66a82479cc65444cbb58d2efc85d8df5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_66a82479cc65444cbb58d2efc85d8df5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.54675310232232%2C%20126.99637872041369%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...
