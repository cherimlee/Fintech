# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
subwayfee = pd.read_csv("./data/subwayfee.csv", encoding='ansi')
df = pd.read_csv("./data/subwaytime.csv", encoding='ansi')
df
# Out:
#          사용월    호선명     역ID        지하철역 04:00:00~04:59:59 Unnamed: 5  \
# 0        NaN    NaN     NaN         NaN                승차         하차
# 1    2019-01    1호선   150.0         서울역               927         22
# 2    2019-01    1호선   151.0          시청                74          0
# 3    2019-01    1호선   152.0          종각               100          8
# 4    2019-01    1호선   153.0        종로3가               122          4
# ..       ...    ...     ...         ...               ...        ...
# 594  2019-01  우이신설선  4709.0      북한산보국문                 5          3
# 595  2019-01  우이신설선  4710.0          정릉                 3          0
# 596  2019-01  우이신설선  4711.0  성신여대입구(돈암)                 2          0
# 597  2019-01  우이신설선  4712.0          보문                 0          0
# 598  2019-01  우이신설선  4713.0         신설동                17          1
#
#     05:00:00~05:59:59 Unnamed: 7 06:00:00~06:59:59 Unnamed: 9  ...  \
# 0                  승차         하차                승차         하차  ...
# ...

# %%
df["Unnamed: 7"]
# Out:
# 0        하차
# 1      8774
# 2      4049
# 3      5105
# 4      2520
#        ...
# 594     561
# 595     625
# 596     281
# 597     190
# 598     725
# Name: Unnamed: 7, Length: 599, dtype: object

# %%
df = df.set_index("지하철역")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, nan to 신설동
# Data columns (total 51 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   사용월                598 non-null    object
#  1   호선명                598 non-null    object
#  2   역ID                598 non-null    float64
#  3   04:00:00~04:59:59  599 non-null    object
#  4   Unnamed: 5         599 non-null    object
#  5   05:00:00~05:59:59  599 non-null    object
#  6   Unnamed: 7         599 non-null    object
#  7   06:00:00~06:59:59  599 non-null    object
#  8   Unnamed: 9         599 non-null    object
#  9   07:00:00~07:59:59  599 non-null    object
#  10  Unnamed: 11        599 non-null    object
#  11  08:00:00~08:59:59  599 non-null    object
#  12  Unnamed: 13        599 non-null    object
#  13  09:00:00~09:59:59  599 non-null    object
#  14  Unnamed: 15        599 non-null    object
#  15  10:00:00~10:59:59  599 non-null    object
# ...

# %%
df.head()
# Out:
#           사용월  호선명    역ID 04:00:00~04:59:59 Unnamed: 5 05:00:00~05:59:59  \
# 지하철역
# NaN       NaN  NaN    NaN                승차         하차                승차
# 서울역   2019-01  1호선  150.0               927         22             10682
# 시청    2019-01  1호선  151.0                74          0              2409
# 종각    2019-01  1호선  152.0               100          8              4409
# 종로3가  2019-01  1호선  153.0               122          4              5061
#
#      Unnamed: 7 06:00:00~06:59:59 Unnamed: 9 07:00:00~07:59:59  ...  \
# 지하철역                                                            ...
# NaN          하차                승차         하차                승차  ...
# 서울역        8774             13504      45545             39110  ...
# 시청         4049              3532      19241              7703  ...
# 종각         5105              4593      26969              6733  ...
# 종로3가       2520              3876      12832              6066  ...
#
# ...

# %%
# 전처리
# 출근시간에 승차인원이 가장 많은 역과 하차인원이 가장 많은 역을 출력하시오

# %%
df.dropt(0. inplace=True)
# Out:
#   File "C:\Users\bitcamp\AppData\Local\Temp/ipykernel_10468/142262429.py", line 1
#     df.dropt(0. inplace=True)
#                 ^
# SyntaxError: invalid syntax

# %%
df.drop(['사용월','역'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10468/3855679563.py in <module>
# ----> 1 df.drop(['사용월','역'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df = df.set_index("지하철역")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10468/3206224547.py in <module>
# ----> 1 df = df.set_index("지하철역")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['지하철역'] are in the columns"

# %%
for c in df.columns:
    df[c] = df[c].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10468/372683301.py in <module>
#       1 for c in df.columns:
# ----> 2     df[c] = df[c].astype('float')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...
